# %%
import sys
sys.path.append('..')
from helpers import maps

# %%
fig, ax, inset_ax = maps.spain_outline('provincias')
handles, labels = ax.get_legend_handles_labels()

maps.add_area('provincias', '5', ax, inset_ax, handles, alpha=0.7, color='red')
maps.add_area('provincias', '12', ax, inset_ax, handles, alpha=0.4, color='green')
maps.add_area('provincias', '38', ax, inset_ax, handles, alpha=0.9, color='purple')

ax.legend(handles=handles, loc='lower left', fontsize='small')
